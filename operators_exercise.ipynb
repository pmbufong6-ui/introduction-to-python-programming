# %% [markdown]
# ## Objective
# This notebook contains solutions to python practice exercises.

# %%
a= 10
b= 5

# %% [markdown]
# ## 1. Calculate the sum of two numbers using the addition operator

# %%
sum_result= a+b
print("Sum:", sum_result)
# Out:
# Sum: 15

# %% [markdown]
# ##2. Find the difference betwwen two numbers using the subtraction operator

# %%
difference= a-b
print("Difference:",difference)
# Out:
# Difference: 5

# %% [markdown]
# #3. Multiply two numbers using the multiplication operator

# %%
product = a*b
print("Product:",product)
# Out:
# Product: 50

# %% [markdown]
# ## 4. Divide two numbers using the division operator

# %%
division= a/b
print("Division:",division)
# Out:
# Division: 2.0

# %% [markdown]
# ## 5. Calculate the remainder using the modulus

# %%
remainder= a%b
print("Remainder:", remainder)
# Out:
# Remainder: 0

# %% [markdown]
# ## 6. Raise a number to a power using the exponential operator

# %%
power= a**2
print("Power:",power)
# Out:
# Power: 100

# %% [markdown]
# ## 7. Check if a number is divisible by both 3 and 5

# %%
number = 15
result= (number % 3 ==0) and (number % 5==0)
print(result)
# Out:
# True

# %% [markdown]
# ## 8. Check if two numbers are equal

# %%
print(a == b)
# Out:
# False

# %% [markdown]
# ## 9. Check if one number is greater than another

# %%
print(a>b)
# Out:
# True

# %% [markdown]
# ## 10. Check if one number is less than another

# %%
print(a<b)
# Out:
# False

# %% [markdown]
# ## 11. Check if one number is greater than or equal to another

# %%
print(a >= b)
# Out:
# True

# %% [markdown]
# ## 12. Check if one number is less than or equal to another

# %%
print(a <= b)
# Out:
# False

# %% [markdown]
# ## 13. Check if two values are not equal

# %%
print(a != b)
# Out:
# True
